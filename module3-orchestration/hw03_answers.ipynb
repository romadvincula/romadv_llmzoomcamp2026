# %% [markdown]
# ## Question 1: Context Engineering
# Try the following experiment:
#
# Open ChatGPT in a private browser window: https://chatgpt.com
#
# Enter this prompt:
#     "Create a Kestra flow that loads NYC taxi data from CSV to BigQuery"
#
# Then, use Kestra's AI Copilot with the same prompt
#
# After trying the same prompt in ChatGPT vs Kestra's AI Copilot, what is the primary reason AI Copilot generates better Kestra flows?
#
# - AI Copilot uses a more powerful model
# - AI Copilot has access to current Kestra plugin documentation
# - AI Copilot uses more tokens
# - AI Copilot has internet access
#
# Answer: AI Copilot has access to current Kestra plugin documentation

# %% [markdown]
# ## Question 2: RAG vs No RAG
# Run both 1_chat_without_rag.yaml and 2_chat_with_rag.yaml in the Kestra UI. Read the execution logs for each.
#
# The non-RAG response about Kestra 1.1 features is best described as:
#
# - Accurate and specific, matching the actual release notes
# - Vague, generic, or fabricated — the model guesses from training data
# - Empty — the model refuses to answer without context
# - Identical to the RAG version
#
# Below is the response from the Non-RAG LLM prompt after running 1_chat_without_rag.yaml:
#
#     Kestra 1.1 introduced a number of notable features and improvements. Here are **5+ major ones** with brief descriptions:
#
#     1. **Plugins Marketplace / Plugin Management Improvements**
#        Kestra 1.1 made it easier to discover, install, and manage plugins, expanding what workflows can do without custom code.
#
#     2. **Enhanced Execution UI**
#        The web UI received improvements for tracking executions, inspecting task logs, and debugging flows more easily.
#
#     3. **Better Flow Design and Editing Experience**
#        Updates to flow authoring made it simpler to create and maintain workflows, especially for larger or more complex pipelines.
#
#     4. **New/Improved Triggers and Scheduling Capabilities**
#        Kestra expanded trigger options, helping workflows start from more event sources and schedule patterns.
#
#     5. **Performance and Scaling Improvements**
#        Under-the-hood changes improved execution handling, reliability, and overall performance for larger deployments.
#
#     6. **Security and Access Control Enhancements**
#        Kestra 1.1 included improvements to authentication/authorization and platform security features for production use.
#
#     7. **Additional Task/Plugin Support**
#        More built-in tasks and integrations were added or improved, making it easier to connect with external systems and services.
#
#     If you want, I can also provide:
#     - a **more exact changelog-style list** from the Kestra 1.1 release notes, or
#     - a **comparison of Kestra 1.0 vs 1.1**.
#
# Answer: Vague, generic, or fabricated — the model guesses from training data

# %% [markdown]
# ## Question 3: Token usage — short summary
# Run 4_simple_agent.yaml with summary_length = short (leave the other inputs as defaults).
#
# Open the execution logs and find the token usage logged by the log_token_usage task.
#
# What is the approximate output token count for multilingual_agent?
#
# - 5-15 tokens
# - 60-100 tokens
# - 200-400 tokens
# - 500+ tokens
#
# Below is the output of log_token_usage task:
#
#     2026-06-26 16:57:31.854📊 Token Usage Summary:
#
#     Multilingual Agent:
#     - Input tokens: 282
#     - Output tokens: 93
#     - Total tokens: 375
#     -
#     English Brevity Agent:
#     - Input tokens: 108
#     - Output tokens: 31
#     - Total tokens: 139
#
#     💡 Tip: Monitor token usage to understand costs and optimize prompts!
#
# The Multilingual Agent consumed 93 output tokens.
#
# Answer: 60-100 tokens

# %% [markdown]
# Question 4: Token usage — long summary
#
# Run 4_simple_agent.yaml again with summary_length = long.
#
# Compare the multilingual_agent output token count to your result from Question 3. Roughly how many times more output tokens does the long summary use?
#
# Below is the output of log_token_usage task:
#
# - About the same (within 20%)
# - 2-5x more
# - 10-20x more
# - 50x more
#
# Below is the output of log_token_usage task:
#
#     INFO 2026-06-26T07:05:55.106075Z 📊 Token Usage Summary:
#
#     Multilingual Agent:
#     - Input tokens: 282
#     - Output tokens: 206
#     - Total tokens: 488
#
#     English Brevity Agent:
#     - Input tokens: 221
#     - Output tokens: 39
#     - Total tokens: 260
#
#     💡 Tip: Monitor token usage to understand costs and optimize prompts!
#
# The output tokens used by the agent was 206 which is within 2 to 5 times more tokens than when using summary_length = small.
#
# Answer: 2-5x more

# %% [markdown]
# ## Question 5: Modifying a flow
#
# Open 4_simple_agent.yaml in the Kestra flow editor. Find the english_brevity task and change its prompt from asking for exactly 1 sentence to asking for exactly 3 sentences.
#
# Save the flow, then run it with summary_length = long.
#
# Compare the english_brevity output token count to the original 1-sentence version (also with summary_length = long). How do they compare?
#
# About the same (within 20%)
# - 2-4x more
# - 5-10x more
# - 10x+ more
#
# Below is the output of log_token_usage task:
#
#     INFO 2026-06-26T07:15:10.007776Z 📊 Token Usage Summary:
#
#     Multilingual Agent:
#     - Input tokens: 282
#     - Output tokens: 176
#     - Total tokens: 458
#
#     English Brevity Agent:
#     - Input tokens: 191
#     - Output tokens: 82
#     - Total tokens: 273
#
#     💡 Tip: Monitor token usage to understand costs and optimize prompts!
#
# The output of each version by the agent is below.
#
# Original Version:
#
#     Kestra is a scalable, open-source orchestration platform that simplifies workflow automation for various applications, including LLM development, by using declarative YAML, a no-code interface, and extensible plugins.
#
# New Version:
#
#     Kestra is an open-source platform enabling declarative workflow orchestration via YAML and a no-code interface, catering to both technical and non-technical users. It offers extensibility through plugins and scripts, supporting use cases from simple schedules to complex data engineering and business process automation. A bonus LLM Zoomcamp module further explores integrating AI technologies like AI Copilot and RAG to enhance workflow development within such platforms.
#
# The original 1 sentence version English Brevity Agent used up 39 output tokens. This version used 82 output tokens which is only about 2 to 4 times more than the original version.
#
# Answer: 2-4x more

# %% [markdown]
# ## Question 6: Best Practices
#
# Based on what you learned in this module, for production workflows requiring deterministic, repeatable results with strict compliance requirements (e.g., financial reporting, workflows in highly regulated industries), which approach is most appropriate?
#
# - Always use AI agents for maximum flexibility and adaptation
# - Use traditional task-based workflows for predictability and auditability
# - Use only RAG without agents for better performance
# - Use web search tools exclusively to ensure current data
#
# LLMs are inheritly probabilistic since their whole premise is predicting the next token based on the previous token so there will always be some risk of getting different output each time they are ran. The general idea of their answer may be the same but there might be minute differences in how they came up to the conclusion. For repeated and deterministic task, it is better to use functions or traditional workflows so that the output will always be the same when using the same input. Another important distinction is the source code of a function can be reviewed and audited unlike an LLM which is a black box.
#
# Answer: Use traditional task-based workflows for predictability and auditability
